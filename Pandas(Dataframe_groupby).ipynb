# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Data_Science\datasets\imdb\IMDb_movies.csv", dtype={'year': str})
df.head(2)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
#
#    year date_published                    genre  duration    country language  \
# 0  1894     1894-10-09                  Romance        45        USA      NaN
# 1  1906     1906-12-26  Biography, Crime, Drama        70  Australia      NaN
#
#           director  ...                                             actors  \
# 0  Alexander Black  ...  Blanche Bayliss, William Courtenay, Chauncey D...
# 1     Charles Tait  ...  Elizabeth Tait, John Tait, Norman Campbell, Be...
#
#                                          description avg_vote votes  budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154     NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589  $ 2250
#
# ...

# %%
df1 = pd.read_csv(r"D:\Data_Science\datasets\imdb\IMDb ratings.csv", dtype={'year': str})
df1.head(2)
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               84954 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
df['genre']=df['genre'].str.split(",").str[0]

# %%
g1=df.groupby('genre')
#g1.sum()

# %%
#g1[['votes']].min()
g1['votes'].min()
# Out:
# genre
# Action         100
# Adult          126
# Adventure      100
# Animation      100
# Biography      100
# Comedy         100
# Crime          100
# Documentary    112
# Drama           99
# Family          99
# Fantasy        100
# Film-Noir      103
# History        102
# Horror         100
# Music          100
# Musical        100
# Mystery        100
# Romance        100
# Sci-Fi         100
# Sport          113
# Thriller        99
# War            100
# Western        100
# Name: votes, dtype: int64

# %%
result = df.groupby('genre').apply(lambda x: x[x['votes'] == x['votes'].min()]).reset_index(drop=True)
result.sample(2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6300\1916878499.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = df.groupby('genre').apply(lambda x: x[x['votes'] == x['votes'].min()]).reset_index(drop=True)
#     imdb_title_id              title     original_title  year date_published  \
# 164     tt0079011        Coccodrillo       Agowa gongpo  1978     1978-10-14
# 135     tt7517232  J'ai perdu Albert  J'ai perdu Albert  2018     2018-09-12
#
#       genre  duration                       country language  \
# 164  Horror       100  South Korea, Thailand, Italy   Korean
# 135  Comedy       100               France, Belgium   French
#
#                   director  ...  \
# ...

# %%
g1.nth(6)
# Out:
#       imdb_title_id                          title  \
# 14        tt0003102     Ma l'amor mio non muore...
# 27        tt0003930       Fantômas contre Fantômas
# 68        tt0006688             Flirting with Fate
# 75        tt0006826                     Hoodoo Ann
# 136       tt0009682             Tarzan of the Apes
# 181       tt0010853                   Wagon Tracks
# 186       tt0010962                    Anna Bolena
# 297       tt0013442         Nosferatu - Il vampiro
# 317       tt0013750  When Knighthood Was in Flower
# 759       tt0020080               The Last Warning
# 866       tt0020785                     Conspiracy
# 897       tt0020949                  Giorni felici
# 2382      tt0027624                    Rocket Ship
# 2712      tt0029043    Quando la vita è un romanzo
# 2780      tt0029361     The Outcasts of Poker Flat
# 2913      tt0029912      The Big Broadcast of 1938
# 3462      tt0032162                      Pinocchio
# ...

# %%
g1.first()
g1.last()
g1.size()
# Out:
# genre
# Action         12182
# Adult              2
# Adventure       3599
# Animation       2108
# Biography       2067
# Comedy         24297
# Crime           5557
# Documentary        2
# Drama          25386
# Family           638
# Fantasy          502
# Film-Noir         29
# History           80
# Horror          5113
# Music             77
# Musical          324
# Mystery          593
# Romance          767
# Sci-Fi           417
# Sport             16
# Thriller        1375
# War              107
# Western          617
# dtype: int64

# %%
g1.get_group("Horror").sample(2)
#g1.groups  #give you index position of each genre category in list
# Out:
#       imdb_title_id                 title        original_title  year  \
# 61439     tt1734067             Atrocious             Atrocious  2010
# 9828      tt0052555  L'amante del vampiro  L'amante del vampiro  1960
#
#       date_published   genre  duration        country language  \
# 61439     2012-06-16  Horror        75  Spain, Mexico  Spanish
# 9828      1960-05-23  Horror        85          Italy  Italian
#
#                     director  ...  \
# 61439  Fernando Barreda Luna  ...
# 9828         Renato Polselli  ...
#
#                                                   actors  \
# 61439  Cristian Valencia, Clara Moraleda, Chus Pereir...
# 9828   Hélène Rémy, Tina Gloriani, Walter Brandi, Isa...
#
#                                              description avg_vote votes  \
# 61439  Two teenage siblings endure a terrifying exper...      5.0  4735
# 9828   A troupe of beautiful young dancers find thems...      5.6   438
#
# ...

# %%
g1.describe()
# Out:
#             duration                                                     \
#                count        mean        std   min    25%    50%     75%
# genre
# Action       12182.0  107.124938  27.745693  45.0  90.00   99.0  119.00
# Adult            2.0   96.500000   2.121320  95.0  95.75   96.5   97.25
# Adventure     3599.0   99.118366  24.743271  45.0  87.00   95.0  106.00
# Animation     2108.0   87.363852  17.051194  41.0  78.00   87.0   96.00
# Biography     2067.0  113.995646  24.957417  45.0  99.00  110.0  124.00
# Comedy       24297.0   97.938799  17.597988  43.0  88.00   95.0  105.00
# Crime         5557.0   98.111931  20.573012  45.0  87.00   95.0  107.00
# Documentary      2.0   88.500000  17.677670  76.0  82.25   88.5   94.75
# Drama        25386.0  102.907508  23.802153  45.0  90.00   99.0  111.00
# Family         638.0   93.481191  18.574441  48.0  84.00   90.0   98.00
# Fantasy        502.0   95.087649  29.053194  45.0  83.00   91.0  101.00
# ...

# %%
g1.nunique()
# Out:
#              imdb_title_id  title  original_title  year  date_published  \
# genre
# Action               12182  11907           11793   106            7298
# Adult                    2      2               2     2               2
# Adventure             3599   3561            3536   109            3084
# Animation             2108   2102            2100    87            1802
# Biography             2067   2057            2049   106            1771
# Comedy               24297  23987           23812   108           11386
# Crime                 5557   5486            5449   106            4486
# Documentary              2      2               2     2               2
# Drama                25386  24727           24595   110           11844
# Family                 638    634             635    80             604
# Fantasy                502    501             501    87             480
# Film-Noir               29     29              29    15              29
# ...

# %%
g1_sum = g1['usa_gross_income'].sum().sort_values(ascending=False) #errror because usa gross margin is object
print(g1_sum)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               84954 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
g1.agg({'votes':'mean','reviews_from_users':'max','duration':'max'})
# Out:
#                     votes  reviews_from_users  duration
# genre
# Action       21309.559432              8869.0       421
# Adult          689.500000                32.0        98
# Adventure    14099.572103              4100.0       485
# Animation    22352.414611              2898.0       190
# Biography    21488.999516              3367.0       442
# Comedy        6435.003251              7639.0       298
# Crime        11601.185892             10472.0       540
# Documentary    615.500000                16.0       101
# Drama         5617.644213              8232.0       808
# Family        1824.485893              1135.0       181
# Fantasy       6909.609562              1299.0       570
# Film-Noir    14085.448276               475.0       111
# History        484.762500                76.0       205
# Horror        6456.789947              3527.0       175
# Music          632.480519                89.0       221
# Musical       1377.333333               418.0       247
# ...

# %%
if 'data1' in globals() or callable(data1) or isinstance(data1,pd.DataFrame):  #callable only work for function else both conditions are good
    del data1
data1=pd.DataFrame(columns=df.columns)
for group,data in g1:
    data1=pd.concat([data1,data[data.votes==data.votes.max()]])
data1[['genre','votes']]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6300\377160563.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data1=pd.concat([data1,data[data.votes==data.votes.max()]])
#              genre    votes
# 48078       Action  2241615
# 16263        Adult     1253
# 50294    Adventure  1449256
# 51427    Animation   974734
# 27629    Biography  1183248
# 31107       Comedy   910502
# 28381        Crime  1780147
# 20189  Documentary     1119
# 28453        Drama  2278845
# 20367       Family   362758
# 33778      Fantasy   323190
# 6344     Film-Noir   155228
# 20764      History     2493
# 18768       Horror   768874
# 65052        Music    16363
# 18462      Musical   232940
# 36475      Mystery  1098879
# 57571      Romance   240237
# ...

# %%
# def func1(data):
#      data['usa_gross_income']=data['usa_gross_income'].str.split().str[1]#.apply(lambda x:x.str.split().str[1])
#     data['usa_gross_income']=data['usa_gross_income'].astype('Int64')
#     print(data['usa_gross_income'].max)
# g1.apply(func1)     #it give whole group to the function

# %%
#df['usa_gross_income']=df['usa_gross_income'].str.split().str[1].astype('Int64')
#df['usa_gross_income']=df['usa_gross_income'].fillna(0)
df.groupby('genre')['usa_gross_income'].max()
# Out:
# genre
# Action                0
# Adult                 0
# Adventure             0
# Animation             0
# Biography             0
# Comedy                0
# Crime          75395035
# Documentary           0
# Drama            100184
# Family                0
# Fantasy               0
# Film-Noir             0
# History               0
# Horror                0
# Music                 0
# Musical               0
# Mystery               0
# Romance               0
# Sci-Fi                0
# Sport                 0
# Thriller              0
# War                   0
# Western               0
# Name: usa_gross_income, dtype: Int64

# %%
df1.isnull().sum()
# Out:
# imdb_title_id                    0
# weighted_average_vote            0
# total_votes                      0
# mean_vote                        0
# median_vote                      0
# votes_10                         0
# votes_9                          0
# votes_8                          0
# votes_7                          0
# votes_6                          0
# votes_5                          0
# votes_4                          0
# votes_3                          0
# votes_2                          0
# votes_1                          0
# allgenders_0age_avg_vote     52496
# allgenders_0age_votes        52496
# allgenders_18age_avg_vote      706
# allgenders_18age_votes         706
# allgenders_30age_avg_vote       10
# allgenders_30age_votes          10
# allgenders_45age_avg_vote       80
# allgenders_45age_votes          80
# males_allages_avg_vote           1
# males_allages_votes              1
# males_0age_avg_vote          58444
# males_0age_votes             58444
# ...

# %%
data1
# Out:
#       imdb_title_id                            title  \
# 48078     tt0468569              Il cavaliere oscuro
# 16263     tt0070696                          Dværgen
# 50294     tt0816692                     Interstellar
# 51427     tt0910970                           WALL·E
# 27629     tt0108052                 Schindler's List
# 31107     tt0120382                  The Truman Show
# 28381     tt0110912                     Pulp Fiction
# 20189     tt0083193                    This Is Elvis
# 28453     tt0111161             Le ali della libertà
# 20367     tt0083866         E.T. - L'extra-terrestre
# 33778     tt0162661      Il mistero di Sleepy Hollow
# 6344      tt0041959                    Il terzo uomo
# 20764     tt0085213                Ballando ballando
# 18768     tt0078748                            Alien
# 65052     tt2172935      Metallica Through the Never
# 18462     tt0077631             Grease - Brillantina
# 36475     tt0209144                          Memento
# ...

# %%
data2=df.iloc[1:20,:]

# %%
pd.concat([data1,data2],keys=['d1','d2']) #ignore_index=True
# Out:
#          imdb_title_id                                              title  \
# d1 48078     tt0468569                                Il cavaliere oscuro
#    16263     tt0070696                                            Dværgen
#    50294     tt0816692                                       Interstellar
#    51427     tt0910970                                             WALL·E
#    27629     tt0108052                                   Schindler's List
#    31107     tt0120382                                    The Truman Show
#    28381     tt0110912                                       Pulp Fiction
#    20189     tt0083193                                      This Is Elvis
#    28453     tt0111161                               Le ali della libertà
#    20367     tt0083866                           E.T. - L'extra-terrestre
#    33778     tt0162661                        Il mistero di Sleepy Hollow
#    6344      tt0041959                                      Il terzo uomo
# ...

# %%
data2.drop(data2.columns[[2,3,4,5,6,7]],axis=1,inplace=True)
data2.drop(index=[11,12,13,14,15,16,17,18,19],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6300\2992923716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.drop(data2.columns[[2,3,4,5,6,7]],axis=1,inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_6300\2992923716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.drop(index=[11,12,13,14,15,16,17,18,19],inplace=True)

# %%
data2.drop(data2.columns[[5]],axis=1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6300\2762919913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.drop(data2.columns[[5]],axis=1,inplace=True)

# %%
data2
# Out:
#    imdb_title_id                                              title language  \
# 1      tt0000574                        The Story of the Kelly Gang      NaN
# 2      tt0001892                                     Den sorte drøm      NaN
# 3      tt0002101                                          Cleopatra  English
# 4      tt0002130                                          L'Inferno  Italian
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...  English
# 6      tt0002423                                     Madame DuBarry   German
# 7      tt0002445                                         Quo Vadis?  Italian
# 8      tt0002452                              Independenta Romaniei      NaN
# 9      tt0002461                                        Richard III  English
# 10     tt0002646                                           Atlantis   Danish
#
#                                  director  \
# 1                            Charles Tait
# ...

# %%
data1.merge(data2,how='inner',on='language').shape
#data2.merge(data1,how='inner',on='language').shape
data2.merge(data1,how='left',on='language').shape
data2.merge(data1,how='right',on='language').shape
#self join( how='' left_on= right_on=)
# Out:
# (41, 29)

# %%
import numpy as np
import re
# np.intersect1d(series1,series2)
h=dir(np)
for k in h:
    if re.findall(r"(\dd)",k):
        print(k)
# Out:
# atleast_1d
# atleast_2d
# atleast_3d
# ediff1d
# histogram2d
# in1d
# intersect1d
# poly1d
# rad2deg
# setdiff1d
# setxor1d
# union1d

# %%
def func2(data):
    return data
result=g1.apply(func2).reset_index(drop=True)
result
