# %%
import pandas as pd
import seaborn as sns

# Load messy dataset (e.g. UFO or air quality)
df = pd.read_csv(r'D:\Data_Science\datasets\UFO\ufo_sighting_data.csv')  # messy date strings in 'Date'
df.head(5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9860\3800223115.py:5: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'D:\Data_Science\datasets\UFO\ufo_sighting_data.csv')  # messy date strings in 'Date'
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        79638 non-null  datetime64[ns]
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80332 non-null  object
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80332 non-null  object
#  10  longitude                        80332 non-null  float64
# dtypes: datetime64[ns](2), float64(1), object(8)
# ...

# %%
df['Date_time'] = pd.to_datetime(df['Date_time'], errors='coerce')
df['date_documented'] = pd.to_datetime(df['date_documented'], errors='coerce')#coerce make unexpected values to nan instaed of 
#raising exception like string to numeric will become null
#to_numeric

# %%
df.head(2)
# Out:
#           Date_time          city state/province country UFO_shape  \
# 0  10/10/1949 20:30    san marcos             tx      us  cylinder
# 1  10/10/1949 21:00  lackland afb             tx     NaN     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
#
#      latitude  longitude
# 0  29.8830556 -97.941111
# 1    29.38421 -98.581082

# %%
df = df.set_index('Date_time').sort_index()
df.sample(2)
# Out:
#                             city state/province country UFO_shape  \
# Date_time
# 1976-09-01 09:00:00  san antonio             tx      us    sphere
# 2005-07-03 22:30:00  tacoma area             wa     NaN   unknown
#
#                     length_of_encounter_seconds  \
# Date_time
# 1976-09-01 09:00:00                         5.0
# 2005-07-03 22:30:00                         600
#
#                     described_duration_of_encounter  \
# Date_time
# 1976-09-01 09:00:00                       5 seconds
# 2005-07-03 22:30:00                      10 minutes
#
#                                                            description  \
# Date_time
# 1976-09-01 09:00:00  i was about 7years old. my parents and sister ...
# 2005-07-03 22:30:00  was wondering if anyone reported a craft in th...
#
#                     date_documented   latitude   longitude
# Date_time
# 1976-09-01 09:00:00      2008-07-05  29.423889  -98.493333
# 2005-07-03 22:30:00      2005-07-05  47.250795 -122.439892

# %%
df['hour'] = df.index.hour
df['year'] = df.index.year
df['weekday'] = df.index.day_name()
df['month']=df.index.month

# %%
df=df.reset_index()

# %%
df['year']=df['year'].astype("Int16")

# %%
df['delay_days'] = (df['date_documented'] - df.index).dt.days

# %%
df.sample(5)
# Out:
#                             city state/province country UFO_shape  \
# Date_time
# 2007-09-19 22:00:00         webb             ia      us     light
# 2008-05-13 08:10:00  los angeles             ca      us       egg
# 2009-06-11 20:00:00        tempe             az      us    sphere
# 2011-06-15 19:00:00  great falls             mt      us   chevron
# 2008-09-06 22:00:00  baton rouge             la      us  triangle
#
#                     length_of_encounter_seconds  \
# Date_time
# 2007-09-19 22:00:00                       420.0
# 2008-05-13 08:10:00                         120
# 2009-06-11 20:00:00                        1200
# 2011-06-15 19:00:00                          10
# 2008-09-06 22:00:00                        60.0
#
#                     described_duration_of_encounter  \
# Date_time
# 2007-09-19 22:00:00                           7min.
# 2008-05-13 08:10:00                       2 minutes
# 2009-06-11 20:00:00                      20 minutes
# ...

# %%
df.loc['2000']
df[df.index.month==11]
df[df.index.year==2011]
df[df.index.hour==0]
df[df.index.weekday==2]
# Out:
#                                               city state/province country  \
# Date_time
# 1910-06-01 15:00:00                    wills point             tx      us
# 1916-04-05 13:00:00  france (above; from aircraft)            NaN     NaN
# 1942-07-15 01:00:00                         oneida             tn      us
# 1945-08-08 12:00:00               huntington beach             ca      us
# 1946-12-25 13:00:00               yokohama (japan)            NaN     NaN
# ...                                            ...            ...     ...
# 2014-05-07 20:30:00                        visalia             ca      us
# 2014-05-07 21:00:00                       theodore             al      us
# 2014-05-07 21:10:00                      naugatuck             ct      us
# 2014-05-07 21:20:00                      hillsboro             mo      us
# 2014-05-07 23:30:00                     san isidro             nm     NaN
#
#                      UFO_shape length_of_encounter_seconds  \
# ...

# %%
df['duration_sec'] = df['length_of_encounter_seconds'].str.extract(r'(\d+)').astype(float)

# %%
df1 = pd.DataFrame({'col': ['A123B456', 'C789D012','C789D012K12','789D012','789012']})
result = df1['col'].str.extractall(r'([A-Z])(\d+)')
result
# Out:
#          0    1
#   match
# 0 0      A  123
#   1      B  456
# 1 0      C  789
#   1      D  012
# 2 0      C  789
#   1      D  012
#   2      K   12
# 3 0      D  012

# %%
#str.match() return boolean series  match pattern at start only
#str.contains() return boolean series match specific pattern wherever it exist in string
#str.fullmatch() return boolean series  match full pattern  start to end must exist as it is 
#str.findall() give you list
