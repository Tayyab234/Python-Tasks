# %%
import pandas as pd
df=pd.read_csv(r"D:\datasets\messi dataset\my_file.csv")
df
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %% [raw]
# #tour title contain irregular values should be remove ( accuracy)
# #$ sign should be remove and there is some text as well from Actual gross and adjusted gross
# #all time peak contain NULL values should be adjusted
# #peak values shpuld also be adjusted
# #year columns should be split into start year and end year
# #feature engineering
# #month columns will be add

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      object
#  2   All Time Peak                     6 non-null      object
#  3   Actual gross                      20 non-null     object
#  4   Adjusted gross (in 2022 dollars)  20 non-null     object
#  5   Artist                            20 non-null     object
#  6   Tour title                        20 non-null     object
#  7   Year(s)                           20 non-null     object
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     object
#  10  Ref.                              20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %%
df.sample(1)
# Out:
#     Rank Peak All Time Peak     Actual gross Adjusted gross (in 2022 dollars)  \
# 18    19  NaN           NaN  $167,700,000[e]                     $204,486,106
#
#    Artist       Tour title    Year(s)  Shows Average gross  Ref.
# 18  Adele  Adele Live 2016  2016–2017    121    $1,385,950  [25]

# %%
import re
df['Tour title'] = df['Tour title'].str.replace(r'[^A-Za-z0-9 .&\-]', '', regex=True).str.strip()

# %%
import re

def clean_title(title):
    # 1. Keep only valid characters
    cleaned = re.sub(r'[^A-Za-z0-9 .&\-]', '', title)
    
    # 2. Remove short garbage tokens like "4a", "v2", "r1", etc.
    cleaned = re.sub(r'\b[a-zA-Z]?\d+[a-zA-Z]?\b', '', cleaned)
    
    # 3. Normalize whitespace
    cleaned = re.sub(r'\s{2,}', ' ', cleaned).strip()
    
    return cleaned
df['Tour title'] = df['Tour title'].apply(lambda x: clean_title(x))

# %%
df1=df.copy()

# %%
df1['Actual gross']=df1['Actual gross'].str.split('$').get(1)
# Out:
#     Rank   Peak All Time Peak     Actual gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...
